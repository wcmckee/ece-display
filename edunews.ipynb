# %%
import requests
import bs4

# %%
reqnew = requests.get('http://www.education.govt.nz/news/')

# %%
newsoup = bs4.BeautifulSoup(reqnew.text)

# %%
print newsoup.find_all('li')
# Out:
# [<li><a href="/news/#main-content-link">Skip to main content</a></li>, <li><a href="/news/#primary-nav-link">Skip to primary navigation</a></li>, <li><a href="/news/#access-keys-link">Skip to access keys</a></li>, <li><a href="/header-utilities/about-us/">About us</a>
# </li>, <li><a href="/header-utilities/contact-us/">Contact us</a>
# </li>, <li id="page-head-search">
# <form action="search/SearchForm" id="page-head-search-form">
# <label for="page-head-search-term"><span>Search</span></label>
# <div id="page-head-search-wrapper">
# <div class="inner">
# <input accesskey="3" id="page-head-search-term" name="Search" value=""/>
# <button class="action" id="page-head-search-form_action_results" name="action_results" type="submit" value="Go">
# Search
# </button>
# </div>
# </div>
# </form>
# </li>, <li id="menu-toggle-wrapper">
# <a href="/news/#menu-toggle"><span>Menu</span></a>
# ...
