# %%
import bs4
import requests
import dominate
from dominate.tags import *
import os
import shutil
import json
from urlparse import urlparse
from bs4 import BeautifulSoup

# %%
reqgov = requests.get('https://www.govt.nz/')

# %%
reqgov.text
# Out:
# u'<!DOCTYPE html>\r\n<html class="no-js" lang="en-NZ">\r\n<head>\r\n    <meta charset="utf-8" />\r\n\r\n    <title>Information and services | New Zealand Government</title>\r\n    <meta name="google-site-verification" content="BDC1GidWagtZ4CFloZKnpbnGkfer99DVp0vjNbjgRlw" />\r\n    <meta name="google-site-verification" content="CYiQrbskgxzabEwsDz-EcS3MkJGqnXanBvb6GEsjNAk" />\r\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n    <meta name="viewport" content="width=device-width, initial-scale=1">\r\n\r\n    \r\n\r\n    \r\n    \r\n    <base href="https://www.govt.nz/"><!--[if lte IE 6]></base><![endif]-->\r\n\r\n    <meta name="ga-tracking-config" data-tracking-id="UA-40749801-1"/>\r\n\r\n    \r\n<link rel="shortcut icon" href="/favicon.png">\r\n\r\n<link rel="apple-touch-icon" sizes="152x152" href="https://www.govt.nz/themes/dia-theme/images/touch-icons/apple-touch-icon-152x152.png">\r\n\r\n<link rel="apple-touch-icon" sizes="144x144" href="https://www.govt.nz/themes/dia
# ...
